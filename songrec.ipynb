# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
df = pd.read_csv ('sussy.csv', encoding = 'utf-8')
print(df.head())
print('There are', df.shape[0], 'songs and', df.shape[1], 'features')
# Out:
#    acousticness                                       analysis_url  \
# 0        0.0140  https://api.spotify.com/v1/audio-analysis/14gm...
# 1        0.4590  https://api.spotify.com/v1/audio-analysis/1Fhb...
# 2        0.7650  https://api.spotify.com/v1/audio-analysis/6D6H...
# 3        0.0935  https://api.spotify.com/v1/audio-analysis/2hA6...
# 4        0.1940  https://api.spotify.com/v1/audio-analysis/7DF8...
#
#                     artist                                       artist_links  \
# 0                    keshi  https://open.spotify.com/artist/3pc0bOVB5whxmD...
# 1                    keshi  https://open.spotify.com/artist/3pc0bOVB5whxmD...
# 2                    keshi  https://open.spotify.com/artist/3pc0bOVB5whxmD...
# 3               Juice WRLD  https://open.spotify.com/artist/4MCBfE4596Uoi2...
# 4  Juice WRLD | SUGA | BTS  https://open.spotify.com/artist/4MCBfE4596Uoi2...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.622       193373   0.671  14gmLQPNYokqB8OKxAp69f
# 1         0.711       166023   0.747  1Fhb9iJPufNMZSwupsXiRe
# 2         0.691       227032   0.389  6D6HVKe7Qu3imn4zzJD0W9
# 3         0.619       230094   0.622  2hA6oxAuJI94AydLWQ2qEU
# 4         0.603       226149   0.771  7DF8lvLdV3htIbuTWpc7lR
#
#    instrumentalness  key  ...                                  name  \
# 0               0.0    5  ...                       War With Heaven
# 1               0.0    0  ...                            beside you
# 2               0.0    4  ...                                 drunk
# 3               0.0    6  ...                            Feel Alone
# 4               0.0    9  ...  Girl Of My Dreams (with SUGA of BTS)
#
#    release_date  popularity speechiness    tempo  time_signature  \
# 0    2021-09-03          69      0.0260   84.996               4
# 1    2021-04-23          76      0.0523  136.000               4
# 2    2020-10-23          72      0.0367  104.952               4
# 3    2021-12-10          76      0.0461  150.062               4
# 4    2021-12-10          86      0.0627  139.988               4
#
#                                           track_href            type  \
# 0  https://api.spotify.com/v1/tracks/14gmLQPNYokq...  audio_features
# 1  https://api.spotify.com/v1/tracks/1Fhb9iJPufNM...  audio_features
# 2  https://api.spotify.com/v1/tracks/6D6HVKe7Qu3i...  audio_features
# 3  https://api.spotify.com/v1/tracks/2hA6oxAuJI94...  audio_features
# 4  https://api.spotify.com/v1/tracks/7DF8lvLdV3ht...  audio_features
#
#                                     uri valence
# 0  spotify:track:14gmLQPNYokqB8OKxAp69f   0.572
# 1  spotify:track:1Fhb9iJPufNMZSwupsXiRe   0.852
# 2  spotify:track:6D6HVKe7Qu3imn4zzJD0W9   0.306
# 3  spotify:track:2hA6oxAuJI94AydLWQ2qEU   0.194
# 4  spotify:track:7DF8lvLdV3htIbuTWpc7lR   0.332
#
# [5 rows x 23 columns]
# There are 613 songs and 23 features

# %%
print('There are', df.isnull().sum().sum(), 'NA values in the dataset')
# Out:
# There are 0 NA values in the dataset

# %%
df.nunique()
# Out:
# acousticness        518
# analysis_url        613
# artist              406
# artist_links        406
# danceability        375
# duration_ms         584
# energy              378
# id                  613
# instrumentalness    347
# key                  12
# liveness            392
# loudness            578
# mode                  2
# name                596
# release_date        395
# popularity           80
# speechiness         427
# tempo               597
# time_signature        4
# track_href          613
# type                  1
# uri                 613
# valence             429
# dtype: int64

# %%
df = df.drop(columns = 'type')

# %%
print(df.info())
df = df.convert_dtypes()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 613 entries, 0 to 612
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   acousticness      613 non-null    float64
#  1   analysis_url      613 non-null    object
#  2   artist            613 non-null    object
#  3   artist_links      613 non-null    object
#  4   danceability      613 non-null    float64
#  5   duration_ms       613 non-null    int64
#  6   energy            613 non-null    float64
#  7   id                613 non-null    object
#  8   instrumentalness  613 non-null    float64
#  9   key               613 non-null    int64
#  10  liveness          613 non-null    float64
#  11  loudness          613 non-null    float64
#  12  mode              613 non-null    int64
#  13  name              613 non-null    object
#  14  release_date      613 non-null    object
#  15  popularity        613 non-null    int64
#  16  speechiness       613 non-null    float64
#  17  tempo             613 non-null    float64
#  18  time_signature    613 non-null    int64
#  19  track_href        613 non-null    object
#  20  uri               613 non-null    object
#  21  valence           613 non-null    float64
# dtypes: float64(9), int64(5), object(8)
# memory usage: 105.5+ KB
# None

# %% [markdown]
# Select all relevant features

# %%
dropfeatures = ['analysis_url','artist','artist_links','uri','track_href','release_date','id','name','time_signature','key','mode','duration_ms']
libraryFeatures = df.drop(columns = dropfeatures)

# %%
libraryFeatures
# Out:
#      acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0           0.014         0.622   0.671               0.0     0.304    -6.426
# 1           0.459         0.711   0.747               0.0    0.0957    -6.335
# 2           0.765         0.691   0.389               0.0    0.0941    -8.247
# 3          0.0935         0.619   0.622               0.0     0.226    -5.874
# 4           0.194         0.603   0.771               0.0      0.13    -6.336
# ..            ...           ...     ...               ...       ...       ...
# 608          0.65         0.709   0.548          0.000002     0.133    -8.493
# 609       0.00199         0.768   0.826          0.000374     0.031    -4.904
# 610       0.00122         0.543   0.868               0.0     0.116    -3.836
# 611       0.00647         0.695   0.818          0.000005    0.0219    -5.379
# 612      0.000096         0.436   0.942          0.000438     0.209    -2.206
#
#      popularity  speechiness    tempo  valence
# 0            69        0.026   84.996    0.572
# 1            76       0.0523    136.0    0.852
# 2            72       0.0367  104.952    0.306
# 3            76       0.0461  150.062    0.194
# 4            86       0.0627  139.988    0.332
# ..          ...          ...      ...      ...
# 608          85        0.353   83.995    0.543
# 609          65       0.0335  114.997    0.926
# 610          57       0.0367  116.145    0.308
# 611          74       0.0334  119.965    0.916
# 612          65       0.0496  164.975      0.5
#
# [613 rows x 10 columns]

# %%
current_track = pd.read_csv ('userTrack.csv')

# %%
track_features = current_track.drop(columns = dropfeatures)
track_features = track_features.drop(columns = ['type'])

# %%
concation = pd.concat([track_features,libraryFeatures])

# %%
standardscaler = StandardScaler()
features_scaled = standardscaler.fit_transform(concation)
tracks_scaled = pd.DataFrame(features_scaled)

# 612 -0.746385 -0.298583  2.163101
# 613 -0.575161  1.303977  0.230747
#
# [614 rows x 10 columns]

# %%
similarity = pd.DataFrame(cosine_similarity(tracks_scaled[1:],tracks_scaled[0:1]),columns = ['cosine_similarity'])
similarity.describe()
# Out:
#        cosine_similarity
# count         613.000000
# mean           -0.023146
# std             0.322467
# min            -0.663315
# 25%            -0.240503
# 50%            -0.055835
# 75%             0.152803
# max             1.000000

# %%
all_df = pd.concat([similarity,df],axis = 1)

# %%
print('Name: ', current_track['name'][0])
print('Artist: ', current_track['artist'][0])
# Out:
# Name:  DROP IT
# Artist:  SLANDER | Basstrick

# %%
all_df.nlargest(10,['cosine_similarity'])
# Out:
#      cosine_similarity  acousticness  \
# 384           1.000000        0.0224
# 264           0.953970       0.00632
# 395           0.950902       0.00419
# 374           0.936478       0.00093
# 585           0.919582        0.0262
# 180           0.916356        0.0142
# 133           0.890070       0.00405
# 263           0.874986       0.00133
# 410           0.872554        0.0266
# 113           0.852981        0.0111
#
#                                           analysis_url  \
# 384  https://api.spotify.com/v1/audio-analysis/5sys...
# 264  https://api.spotify.com/v1/audio-analysis/1KN7...
# 395  https://api.spotify.com/v1/audio-analysis/6Ulv...
# 374  https://api.spotify.com/v1/audio-analysis/5IAN...
# 585  https://api.spotify.com/v1/audio-analysis/7wC9...
# 180  https://api.spotify.com/v1/audio-analysis/67Vl...
# 133  https://api.spotify.com/v1/audio-analysis/58qe...
# 263  https://api.spotify.com/v1/audio-analysis/0yfg...
# 410  https://api.spotify.com/v1/audio-analysis/70nT...
# 113  https://api.spotify.com/v1/audio-analysis/0PJ4...
#
#                      artist  \
# 384     SLANDER | Basstrick
# 264         Rawtek | Schade
# 395          Valentino Khan
# 374                  Mercer
# 585                 Sikdope
# 180                   Kayzo
# 133          Gerald Le Funk
# 263                Borgeous
# 410                Riot Ten
# 113  Steve Angello | BROHUG
#
#                                           artist_links  danceability  \
# 384  https://open.spotify.com/artist/20DZAfCuP1TKZl...         0.813
# 264  https://open.spotify.com/artist/6LiWlIUtgDUn83...         0.707
# 395  https://open.spotify.com/artist/0deIjoDjl9g9Zp...         0.792
# 374  https://open.spotify.com/artist/7aSsnDTH11xS2y...         0.732
# 585  https://open.spotify.com/artist/3EXfNuPuR3OFEd...          0.86
# 180  https://open.spotify.com/artist/72iCiKwu6nu6Qq...         0.587
# 133  https://open.spotify.com/artist/5oFnSQlO6c7Zzm...         0.741
# 263  https://open.spotify.com/artist/4uiMn2g0pgTrhN...         0.678
# 410  https://open.spotify.com/artist/2Zxy5LwBatI5kw...         0.703
# 113  https://open.spotify.com/artist/4FqPRilb0Ja0TK...         0.808
#
#      duration_ms  energy                      id  instrumentalness  ...  mode  \
# 384       191250   0.966  5sysgWS6HwrfhHDnqMh27l             0.739  ...     1
# 264       211200    0.96  1KN7IN8tKAQy6llwF7PEOo             0.692  ...     0
# 395       184680   0.906  6UlvONcL4jXM0pC0CPA48S             0.586  ...     1
# 374       193899    0.96  5IAN1gv4gFSirldHSMYSJq             0.881  ...     0
# 585       174375   0.956  7wC9cG5EgruIiQe6Xt6SFm             0.722  ...     1
# 180       233600   0.966  67VlPt3to7DT4F2rFLWhw6             0.843  ...     0
# 133       268404   0.914  58qebZyV7A4Gka3vw51EUW             0.792  ...     1
# 263       203437   0.953  0yfgNfht7itLYslEOzmOwq             0.659  ...     1
# 410       231305   0.972  70nTmaiN7Js36XCmURYUTF             0.775  ...     1
# 113       201120   0.752  0PJ4RVL5wCeHDO8wHpk3YG             0.927  ...     0
#
#                     name  release_date  popularity speechiness    tempo  \
# 384              DROP IT    2017-05-19          35       0.154  128.006
# 264              My Vibe    2019-11-08          32       0.186  149.954
# 395        Deep Down Low    2015-03-17          42      0.0592  126.016
# 374            Studio 54    2018-10-04          21      0.0686  120.008
# 585               Snakes    2016-04-18          52      0.0727  128.013
# 180               Say It    2020-09-25          19      0.0714  149.995
# 133               Legacy    2019-05-24          30      0.0808  149.998
# 263          Night & Day    2020-02-28          24      0.0396  128.007
# 410       Lost Your Mind    2020-02-25          25       0.153  125.975
# 113  KNAS - BROHUG Remix    2019-08-30          47      0.0759  125.005
#
#      time_signature                                         track_href  \
# 384               4  https://api.spotify.com/v1/tracks/5sysgWS6Hwrf...
# 264               4  https://api.spotify.com/v1/tracks/1KN7IN8tKAQy...
# 395               4  https://api.spotify.com/v1/tracks/6UlvONcL4jXM...
# 374               4  https://api.spotify.com/v1/tracks/5IAN1gv4gFSi...
# 585               4  https://api.spotify.com/v1/tracks/7wC9cG5EgruI...
# 180               4  https://api.spotify.com/v1/tracks/67VlPt3to7DT...
# 133               4  https://api.spotify.com/v1/tracks/58qebZyV7A4G...
# 263               4  https://api.spotify.com/v1/tracks/0yfgNfht7itL...
# 410               4  https://api.spotify.com/v1/tracks/70nTmaiN7Js3...
# 113               4  https://api.spotify.com/v1/tracks/0PJ4RVL5wCeH...
#
#                                       uri  valence
# 384  spotify:track:5sysgWS6HwrfhHDnqMh27l    0.381
# 264  spotify:track:1KN7IN8tKAQy6llwF7PEOo    0.421
# 395  spotify:track:6UlvONcL4jXM0pC0CPA48S    0.471
# 374  spotify:track:5IAN1gv4gFSirldHSMYSJq    0.557
# 585  spotify:track:7wC9cG5EgruIiQe6Xt6SFm   0.0794
# 180  spotify:track:67VlPt3to7DT4F2rFLWhw6    0.379
# 133  spotify:track:58qebZyV7A4Gka3vw51EUW    0.177
# 263  spotify:track:0yfgNfht7itLYslEOzmOwq    0.564
# 410  spotify:track:70nTmaiN7Js36XCmURYUTF    0.178
# 113  spotify:track:0PJ4RVL5wCeHDO8wHpk3YG    0.469
#
# [10 rows x 23 columns]
